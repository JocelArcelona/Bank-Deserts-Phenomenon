# %%
import pandas as pd 
import csv 
import geopandas as gpd
import os
from shapely.geometry import Point
from geopy.distance import geodesic
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Feature Engineering the Target Variable (Bank Desert Status)
# - This bank desert status is measured in the census tract level
# - Conditions for the target variable: The bank desert status (bank desert, potential bank desert, not a bank desert) is determined by a few factors including the community type (2 miles for Urban, 5 miles for Suburban and 10 miles for Rural), if the distance between the center of a census tract (depending on the community type) and the nearest bank branch is greater than the community type mileage, the census tract is a bank desert.
# ##### The logic is as follows:
# - For each census tract (geoid) in the shapefile:
# You calculate the center (centroid) of that census tract.
#
#
# - For each bank in the bank dataset:
# You check if the bank's geoid matches the current census tract's geoid.
# If the bank is in the same geoid, you calculate the distance between the center of the census tract and each bank location.
#
#
# - Determine the bank desert status:
# If there are no banks within the specified radius (based on community type), the census tract is classified as a "bank desert".
# If there is one bank within the specified radius, the census tract is classified as a "potential bank desert".
# If there are multiple banks within the specified radius, the census tract is classified as "not a bank desert".

# %%
# read census tract shapefiles data and bank data 
shp_file_path = '../data/shp_ruca_combined_final.parquet'
bank_file_path = '../data/fdic_ncua_gdf_final.parquet'

cs_shp_gdf = gpd.read_parquet(shp_file_path)
banks_gdf = gpd.read_parquet(bank_file_path)

# %%
cs_shp_gdf
# Out:
#       STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 0          01      063  060101  01063060101  1400000US01063060101  601.01
# 1          01      069  040802  01069040802  1400000US01069040802  408.02
# 2          01      069  040205  01069040205  1400000US01069040205  402.05
# 3          01      069  040203  01069040203  1400000US01069040203  402.03
# 4          01      069  040801  01069040801  1400000US01069040801  408.01
# ...       ...      ...     ...          ...                   ...     ...
# 72213      56      021  000200  56021000200  1400000US56021000200       2
# 72214      56      009  956400  56009956400  1400000US56009956400    9564
# 72215      56      009  956400  56009956400  1400000US56009956400    9564
# 72216      56      009  956400  56009956400  1400000US56009956400    9564
# 72217      56      009  956700  56009956700  1400000US56009956700    9567
#
#                   NAMELSAD  MTFCC FUNCSTAT      ALAND  AWATER   INTPTLAT  \
# 0      Census Tract 601.01  G5020        S   79177219  846346  32.779875
# 1      Census Tract 408.02  G5020        S   31146753  351369  31.149447
# 2      Census Tract 402.05  G5020        S    8597200   89063  31.231052
# 3      Census Tract 402.03  G5020        S   14602533       0  31.261332
# 4      Census Tract 408.01  G5020        S   20146185  217773  31.188587
# ...                    ...    ...      ...        ...     ...        ...
# 72213       Census Tract 2  G5020        S    7538613       0  41.124339
# 72214    Census Tract 9564  G5020        S  121226002  879080  42.796182
# 72215    Census Tract 9564  G5020        S  121226002  879080  42.796182
# 72216    Census Tract 9564  G5020        S  121226002  879080  42.796182
# 72217    Census Tract 9567  G5020        S   26097174  583365  42.844205
#
#          INTPTLON                                           geometry  \
# 0      -87.936632  POLYGON ((-87.99829 32.76851, -87.99326 32.771...
# 1      -85.418679  POLYGON ((-85.44941 31.15536, -85.44937 31.155...
# 2      -85.472151  POLYGON ((-85.50281 31.23736, -85.50261 31.238...
# 3      -85.474245  POLYGON ((-85.50379 31.24638, -85.50281 31.247...
# 4      -85.443952  POLYGON ((-85.47512 31.2079, -85.47504 31.2083...
# ...           ...                                                ...
# 72213 -104.808835  POLYGON ((-104.85109 41.11787, -104.85084 41.1...
# 72214 -105.299046  POLYGON ((-105.42173 42.80178, -105.42172 42.8...
# 72215 -105.299046  POLYGON ((-105.42173 42.80178, -105.42172 42.8...
# 72216 -105.299046  POLYGON ((-105.42173 42.80178, -105.42172 42.8...
# 72217 -105.843209  POLYGON ((-105.90686 42.85549, -105.90675 42.8...
#
#                 source_file Community Type
# 0      tl_2024_01_tract.shp          Urban
# 1      tl_2024_01_tract.shp          Urban
# 2      tl_2024_01_tract.shp          Urban
# 3      tl_2024_01_tract.shp          Urban
# 4      tl_2024_01_tract.shp          Urban
# ...                     ...            ...
# 72213  tl_2024_56_tract.shp          Urban
# 72214  tl_2024_56_tract.shp          Rural
# 72215  tl_2024_56_tract.shp          Rural
# 72216  tl_2024_56_tract.shp          Rural
# 72217  tl_2024_56_tract.shp          Urban
#
# [72218 rows x 16 columns]

# %%
banks_gdf
# Out:
#              City State    ZIP  \
# Index
# 0      Gloucester    MA   1930
# 1           Tampa    FL  33602
# 2        Richmond    MO  64085
# 3         Mendota    IL  61342
# 4      Burlington    CO  80807
# ...           ...   ...    ...
# 70999     Augusta    ME   4330
# 71000  Waterville    ME   4901
# 71001       Boyle    MS  38730
# 71002       Tampa    FL  33619
# 71003     Cordova    TN  38016
#
#                                          Input Address State Code County Code  \
# Index
# 0      102 Rogers St, Gloucester, Massachusetts, 01930         25         009
# 1              401 E Jackson St, Tampa, Florida, 33602         12         057
# 2          803 Wollard Blvd, Richmond, Missouri, 64085         29         177
# 3          706 Washington St, Mendota, Illinois, 61342         17         099
# 4             410 14th St, Burlington, Colorado, 80807         08         063
# ...                                                ...        ...         ...
# 70999           2010 N Belfast Ave, Augusta, Me, 04330         23         011
# 71000           222 College Ave, Waterville, Me, 04901         23         011
# 71001                 630 Gaines Hwy, Boyle, Ms, 38730         28         011
# 71002           9927 Delaney Lake Dr, Tampa, Fl, 33619         12         057
# 71003           1591 Chickering Ln, Cordova, Tn, 38016         47         157
#
#       Tract Code Block Code   Longitude   Latitude      FIPS 11  \
# Index
# 0         221500       2005  -70.658897  42.613537  25009221500
# 1         005101       2079  -82.456675  27.947186  12057005101
# 2         080202       2002  -93.959037  39.269180  29177080202
# 3         961900       4022  -89.118569  41.548092  17099961900
# 4         962100       2065 -102.267955  39.304779  08063962100
# ...          ...        ...         ...        ...          ...
# 70999     010100       3018  -69.762596  44.324040  23011010100
# 71000     024101       1001  -69.614780  44.574180  23011024101
# 71001     950500       2037  -90.718231  33.712482  28011950500
# 71002     013315       1005  -82.341062  27.932052  12057013315
# 71003     021126       1014  -89.795118  35.168678  47157021126
#
#                                                Bank Name  \
# Index
# 0                 Santander Bank, N.A. Gloucester Branch
# 1             Truist Bank Truist Financial Center Branch
# 2                                       Flat Branch Bank
# 3                                       First State Bank
# 4      Farmers & Merchants Bank Of Colby Burlington B...
# ...                                                  ...
# 70999                                       Capital Area
# 71000                                                Ksw
# 71001                              Shelby/Bolivar County
# 71002                                     Grow Financial
# 71003                                          Healthnet
#
#                           Geometry
# Index
# 0        POINT (-70.6589 42.61354)
# 1       POINT (-82.45667 27.94719)
# 2       POINT (-93.95904 39.26918)
# 3       POINT (-89.11857 41.54809)
# 4      POINT (-102.26795 39.30478)
# ...                            ...
# 70999    POINT (-69.7626 44.32404)
# 71000   POINT (-69.61478 44.57418)
# 71001   POINT (-90.71823 33.71248)
# 71002   POINT (-82.34106 27.93205)
# 71003   POINT (-89.79512 35.16868)
#
# [70998 rows x 13 columns]

# %%
# count of banks per census tract 
# FIPS 11 == GEOID
bank_counts = banks_gdf.groupby("FIPS 11").size().reset_index(name="bank_count")
bank_counts
# Out:
#            FIPS 11  bank_count
# 0      01001020200           1
# 1      01001020501           1
# 2      01001020502           4
# 3      01001020600           1
# 4      01001020700           2
# ...            ...         ...
# 33241  72141957500           1
# 33242  72147950600           1
# 33243  72149720400           1
# 33244  72151951000           1
# 33245  78010970300           1
#
# [33246 rows x 2 columns]

# %%
# how many unique GEOIDs in the bank data are in the census shapefile 

# matching_geoid = cs_shp_gdf[cs_shp_gdf['GEOID'].isin(banks_gdf['FIPS 11'])]
# matching_geoid

matching_geoid = bank_counts[bank_counts['FIPS 11'].isin(cs_shp_gdf['GEOID'])]
matching_geoid
# Out:
#            FIPS 11  bank_count
# 1      01001020501           1
# 3      01001020600           1
# 4      01001020700           2
# 7      01003010704           1
# 11     01003010800           4
# ...            ...         ...
# 33172  56039967701           8
# 33176  56041975301           1
# 33178  56043000301           6
# 33179  56045951100           1
# 33180  56045951300           2
#
# [24262 rows x 2 columns]

# %% [markdown]
# - 28927 GEOID in the census shapefiles dataframe exists in the FIPS 11 in banks dataframe
# - 51466 GEOID in the banks dataframe exists in the census shapefile dataframe
# - There are only 24262 unique GEOIDs from the bank dataframe that is available in the census shapefile data

# %%
# how many unique GEOIDs are in both dataframes?
# the census tract shapefile data has a total of 72218 rows but only 60742 unique GEOID, which means some GEOIDs are duplicated
cs_shp_gdf['GEOID'].nunique()
# Out:
# 60742

# %%
banks_gdf['FIPS 11'].nunique()
# Out:
# 33246

# %% [markdown]
# - Some of the GEOID in the census tract shapefile dataframe is duplicated, this could be causing some discrepancy in the classification of census tract bank desert status
# - Each census tract from the census tract shapefile data has to be have a unique bank desert status, it can't be duplicated

# %%
# Drop duplicated rows based on the GEOID column
# after running the code below, we only have 60742 rows left with unique GEOID 
cs_shp_gdf = cs_shp_gdf.drop_duplicates(subset='GEOID', keep = 'first').reset_index(drop = True)

# %%
# feature engineer radius distance threshold based on community type in miles 

cs_shp_gdf['Radius Threshold in Miles'] = cs_shp_gdf['Community Type'].apply(lambda x: 2 if x == 'Urban'
                                                                            else 5 if x == 'Suburban'
                                                                            else 10)

# %%
print(cs_shp_gdf.crs)  # check the CRS of the census shapefile GeoDataFrame
print(banks_gdf.crs)    # check the CRS of the banks GeoDataFrame
# Out:
# {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "NAD83", "datum": {"type": "GeodeticReferenceFrame", "name": "North American Datum 1983", "ellipsoid": {"name": "GRS 1980", "semi_major_axis": 6378137, "inverse_flattening": 298.257222101}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Geodesy.", "area": "North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.", "bbox": {"south_latitude": 14.92, "west_longitude": 167.65, "north_latitude": 86.45, "east_longitude": -40.73}, "id": {"authority": "EPSG", "code": 4269}}
# None

# %%
cs_shp_gdf.set_crs(epsg=4269, inplace=True)
banks_gdf.set_crs(epsg=4269, inplace=True)
# Out:
#              City State    ZIP  \
# Index
# 0      Gloucester    MA   1930
# 1           Tampa    FL  33602
# 2        Richmond    MO  64085
# 3         Mendota    IL  61342
# 4      Burlington    CO  80807
# ...           ...   ...    ...
# 70999     Augusta    ME   4330
# 71000  Waterville    ME   4901
# 71001       Boyle    MS  38730
# 71002       Tampa    FL  33619
# 71003     Cordova    TN  38016
#
#                                          Input Address State Code County Code  \
# Index
# 0      102 Rogers St, Gloucester, Massachusetts, 01930         25         009
# 1              401 E Jackson St, Tampa, Florida, 33602         12         057
# 2          803 Wollard Blvd, Richmond, Missouri, 64085         29         177
# 3          706 Washington St, Mendota, Illinois, 61342         17         099
# 4             410 14th St, Burlington, Colorado, 80807         08         063
# ...                                                ...        ...         ...
# 70999           2010 N Belfast Ave, Augusta, Me, 04330         23         011
# 71000           222 College Ave, Waterville, Me, 04901         23         011
# 71001                 630 Gaines Hwy, Boyle, Ms, 38730         28         011
# 71002           9927 Delaney Lake Dr, Tampa, Fl, 33619         12         057
# 71003           1591 Chickering Ln, Cordova, Tn, 38016         47         157
#
#       Tract Code Block Code   Longitude   Latitude      FIPS 11  \
# Index
# 0         221500       2005  -70.658897  42.613537  25009221500
# 1         005101       2079  -82.456675  27.947186  12057005101
# 2         080202       2002  -93.959037  39.269180  29177080202
# 3         961900       4022  -89.118569  41.548092  17099961900
# 4         962100       2065 -102.267955  39.304779  08063962100
# ...          ...        ...         ...        ...          ...
# 70999     010100       3018  -69.762596  44.324040  23011010100
# 71000     024101       1001  -69.614780  44.574180  23011024101
# 71001     950500       2037  -90.718231  33.712482  28011950500
# 71002     013315       1005  -82.341062  27.932052  12057013315
# 71003     021126       1014  -89.795118  35.168678  47157021126
#
#                                                Bank Name  \
# Index
# 0                 Santander Bank, N.A. Gloucester Branch
# 1             Truist Bank Truist Financial Center Branch
# 2                                       Flat Branch Bank
# 3                                       First State Bank
# 4      Farmers & Merchants Bank Of Colby Burlington B...
# ...                                                  ...
# 70999                                       Capital Area
# 71000                                                Ksw
# 71001                              Shelby/Bolivar County
# 71002                                     Grow Financial
# 71003                                          Healthnet
#
#                           Geometry
# Index
# 0        POINT (-70.6589 42.61354)
# 1       POINT (-82.45667 27.94719)
# 2       POINT (-93.95904 39.26918)
# 3       POINT (-89.11857 41.54809)
# 4      POINT (-102.26795 39.30478)
# ...                            ...
# 70999    POINT (-69.7626 44.32404)
# 71000   POINT (-69.61478 44.57418)
# 71001   POINT (-90.71823 33.71248)
# 71002   POINT (-82.34106 27.93205)
# 71003   POINT (-89.79512 35.16868)
#
# [70998 rows x 13 columns]

# %%
# set coordinate reference system of banks geodataframe to the same CRS of shapefile dataframe for a more precise distance calculation
# since our census tracts radius threshold's maximum is only around 10 miles, we can use Euclidean distance, the earth's curvature is negligible in since local areas are small enough

# set the CRS for both dataframes to be the same 
cs_shp_gdf = cs_shp_gdf.to_crs(epsg=4326)
banks_gdf = banks_gdf.to_crs(epsg=4326)

# %% [markdown]
# - Both dataframes, shapefiles and banks, are now using the same coordinate system. EPSG:5070 (NAD83 / Conus Albers) is a suitable U.S. projection for large-scale analyses because it minimizes distortion over the contiguous U.S.

# %%
cs_shp_gdf.isna().sum()
# Out:
# STATEFP                      0
# COUNTYFP                     0
# TRACTCE                      0
# GEOID                        0
# GEOIDFQ                      0
# NAME                         0
# NAMELSAD                     0
# MTFCC                        0
# FUNCSTAT                     0
# ALAND                        0
# AWATER                       0
# INTPTLAT                     0
# INTPTLON                     0
# geometry                     0
# source_file                  0
# Community Type               0
# Radius Threshold in Miles    0
# dtype: int64

# %%
banks_gdf.isna().sum()
# Out:
# City             0
# State            0
# ZIP              0
# Input Address    0
# State Code       0
# County Code      0
# Tract Code       0
# Block Code       0
# Longitude        0
# Latitude         0
# FIPS 11          0
# Bank Name        0
# Geometry         0
# dtype: int64

# %% [markdown]
# #### Explanation regarding the bank desert status function below
# - The function iterates through the individual rows in census shapefile dataframe, we extract GEOID, Community Type, the Radius Threshold in Miles (this is based on Community Type, 2 miles for Urban, 5 miles for Suburban and 10 miles for Rural), INTPTLAT (internal point latitude) and the INTPTLON (internal point longitude)
# - The GEOID contains the 11 digit FIPS code of the census tract
# - The Community Type is based on the Rural Urban classification taken from the USDA website
# - The Radius Threshold in Miles is the radius threshold defined by the FDIC
# - INTPTLAT and INTPTLON are coordinates that represent the internal point of a geographic area, this is usually the center of the census tract but due to the census tracts having irregular shapes, the internal point may be located in a more central and populated part of the tract rather than the exact geometric center.
#
# - After extracting the columns from the census shapefile dataframe, we filter the bank dataframe based on the GEOID from the census shapefile dataframe (this is done due to a GEOID potentially having multiple banks)
# - Once we have filtered the bank dataframe using the GEOID, we create an empty list called distances_list that will contain the distance between the center of a census tract (intptlat and intptlon) and the bank branch
# - Then we iterate through this filtered bank dataframe, extract the Latitude and Longitude columns, calculate the geodesic distance in miles using the latitude and longitude from the shapefile and bank dataframe and append it to the distances_list
# - Once we have the distances_list of all the banks relative to the census tracts centroid based on GEOID, we classify the census tracts bank desert status based on the number of banks inside the radius threshold:
# if the sum of banks within the radius is 0, that census tract is considered a 'bank desert'
# if the sum of banks within the radius is 1, that census tract is considered a 'potential bank desert'
# if the sum of banks within the radius is other than 0 or 1, that census tract is considered 'not a bank desert'
# - After classifying the status, we assign the bank desert status to the census shapefile dataframe and return the updated dataframe containing the bank desert status variable

# %%
# create a function to classify each census tracts bank desert status 

def bank_desert_status(shapefile_df, bank_df):
    shapefile_df = shapefile_df.reset_index(drop=True)  # reset index to ensure sequential indexing
    
    # loop through each row of the shapefile dataframe to obtain community type, geoid and radius threshold of each census tract 
    for index, shapefile_row in shapefile_df.iterrows():
        geoid = shapefile_row['GEOID']
        radius = shapefile_row['Radius Threshold in Miles']
        
        # census shapefile internal point latitude and longitude -- not always the pertaining to the center of the tract
        census_lat = shapefile_row['INTPTLAT']
        census_lon = shapefile_row['INTPTLON']
        
        # # Get the centroid of the census tract (already reprojected to EPSG:5070)
        # census_point = shapefile_row.geometry
        
        # filter the bank dataframe for banks in each census tract, where GEOID from shapefile_df is equal to FIPS 11 from bank_df 
        banks_in_tract = bank_df[bank_df['FIPS 11'] == geoid]

        # if banks_in_tract is empty which means the GEOID from the shapefile df does not exist in the bank_df, assign 'bank desert'
        if banks_in_tract.empty:
            shapefile_df.loc[index, 'bank_desert_status'] = 'bank desert'
            continue  # skip to next tract if no banks are found
        
        # empty list to store geodesic distances between the census centroid and bank 
        distances_list = []

        # iterate through the filtered bank dataframe, banks where GEOID == FIPS 11
        for _, bank_row in banks_in_tract.iterrows(): 
            # extract bank latitude and longitude 
            bank_lat = bank_row['Latitude']
            bank_lon = bank_row['Longitude']

            # bank_point = bank_row.Geometry
            # # calculate distance in meters
            # distance_meters = census_point.distance(bank_point)

            # # Convert to miles
            # distance_miles = distance_meters * 0.000621371
            # distances_list.append(distance_miles)
            
            # calculate geodesic distance in miles
            distance_miles = geodesic((census_lat, census_lon), (bank_lat, bank_lon)).miles
            distances_list.append(distance_miles)
        print(f"Distances list for {geoid}: {distances_list}")

        # counter for banks within the radius threshold 
        within_radius_count = sum(1 for b in distances_list if b <= radius) 
        print(f"Within radius count for {geoid}: {within_radius_count}")
        
        if not distances_list: # if not distances_list means there are no banks in that census tract 
            bank_desert_status = 'bank desert'
                
        # classify the bank desert status based on the counts
        else:
            if within_radius_count == 0:
                bank_desert_status = 'bank desert'  # no banks within the radius
            elif within_radius_count == 1:
                bank_desert_status = 'potential bank desert'  # one bank within the radius
            else:
                bank_desert_status = 'not a bank desert' # multiple banks within the radius

        # assign the bank desert status to the census shapefile dataframe
        shapefile_df.loc[index, 'bank_desert_status'] = bank_desert_status
            
    # return updated shapefiled_df with bank desert status variable                 
    return shapefile_df

# %%
cs_shp_with_BDS = bank_desert_status(cs_shp_gdf, banks_gdf)
cs_shp_with_BDS
# Out:
# Distances list for 01063060101: [5.024456405884112]
# Within radius count for 01063060101: 0
# Distances list for 01069040205: [0.6224069002641558]
# Within radius count for 01069040205: 1
# Distances list for 01069040203: [1.4851390167251817]
# Within radius count for 01069040203: 1
# Distances list for 01069041901: [2.6984567231097203]
# Within radius count for 01069041901: 0
# Distances list for 01125012101: [0.9547756710264802]
# Within radius count for 01125012101: 1
# Distances list for 01125010304: [1.199887474044709, 1.1361844873146503]
# Within radius count for 01125010304: 2
# Distances list for 01125012001: [0.5278763753574526]
# Within radius count for 01125012001: 1
# Distances list for 01089001902: [0.741735607772277]
# Within radius count for 01089001902: 1
# Distances list for 01089011021: [0.917405067393921]
# Within radius count for 01089011021: 1
# Distances list for 01089001901: [1.744848844748539, 1.6727875464701105, 1.6136238914517496]
# Within radius count for 01089001901: 3
# Distances list for 01089011400: [3.3083172344972223, 2.9737728768662066]
# Within radius count for 01089011400: 0
# Distances list for 01089010612: [0.835963976268393, 0.7954050440955457, 0.9817383316790462, 1.2799102791639705, 2.0112048195532384, 0.7827611698295247, 1.4542433431160757, 0.7721664794095956]
# Within radius count for 01089010612: 7
# Distances list for 01059973600: [5.49398112454821]
# Within radius count for 01059973600: 1
# Distances list for 01059973500: [6.018199356777981]
# Within radius count for 01059973500: 1
# Distances list for 01059973100: [1.5962322426467663]
# Within radius count for 01059973100: 1
# Distances list for 01059973400: [6.275000028407573, 6.303872260868151, 6.216502432733403, 5.719463463053379]
# Within radius count for 01059973400: 4
# Distances list for 01059973000: [2.988152934334192, 2.986840293529047, 2.3133056776583447, 2.246152527464278]
# Within radius count for 01059973000: 0
# Distances list for 01059973200: [1.41601830776009]
# Within radius count for 01059973200: 1
# Distances list for 01127020301: [2.2746075947835953, 2.2642793701867827]
# Within radius count for 01127020301: 0
# Distances list for 01009050104: [4.475535236445186]
# Within radius count for 01009050104: 1
# Distances list for 01089011023: [0.7831000619595523, 0.9285961936390983, 0.6889875963711436]
# Within radius count for 01089011023: 3
# Distances list for 01089001000: [0.3517107123906288]
# Within radius count for 01089001000: 1
# Distances list for 01031011203: [1.1354416740554483]
# Within radius count for 01031011203: 1
# Distances list for 01089001200: [0.7280990882903309]
# Within radius count for 01089001200: 1
# Distances list for 01011952201: [4.274449991495207, 4.064946056683126]
# Within radius count for 01011952201: 0
# Distances list for 01069041000: [0.8589671571752348]
# Within radius count for 01069041000: 1
# Distances list for 01069041100: [0.0494824109000381, 0.6098127660518531]
# Within radius count for 01069041100: 2
# Distances list for 01069041500: [1.8816392235162542]
# Within radius count for 01069041500: 1
# Distances list for 01055010503: [1.9742746110274576]
# Within radius count for 01055010503: 1
# Distances list for 01071950101: [5.014363571924424]
# Within radius count for 01071950101: 0
# Distances list for 01089002911: [0.8741306576319257]
# Within radius count for 01089002911: 1
# Distances list for 01013952800: [0.6999731949407859]
# Within radius count for 01013952800: 1
# Distances list for 01089000701: [0.8173462385744676, 0.5652189652048938]
# Within radius count for 01089000701: 2
# Distances list for 01091972901: [1.3480514167747522, 1.1836738225596388]
# Within radius count for 01091972901: 2
# Distances list for 01033020703: [0.2846190214765563, 0.9423967010346003, 0.8487709894058217, 0.22034414684968043]
# Within radius count for 01033020703: 4
# Distances list for 01097007400: [1.137613887593483]
# Within radius count for 01097007400: 1
# Distances list for 01043964800: [1.290208641543356]
# Within radius count for 01043964800: 1
# Distances list for 01107050401: [3.9112774690871523]
# Within radius count for 01107050401: 0
# Distances list for 01099075901: [10.104267926397464]
# Within radius count for 01099075901: 0
# Distances list for 01089000702: [0.7133934715777079]
# Within radius count for 01089000702: 1
# Distances list for 01101002201: [0.5148838649570219]
# Within radius count for 01101002201: 1
# Distances list for 01101002400: [0.4340126431017646]
# Within radius count for 01101002400: 1
# Distances list for 01101002700: [0.9682166879599067, 0.9899908274545771]
# Within radius count for 01101002700: 2
# Distances list for 01101003301: [0.8716952097738653, 0.8646711882175185, 0.7089018508336041]
# Within radius count for 01101003301: 3
# Distances list for 01097006412: [1.2871604230547518]
# Within radius count for 01097006412: 1
# Distances list for 01097007203: [0.8865455857258321]
# Within radius count for 01097007203: 1
# Distances list for 01119011500: [8.429826422114276, 7.43295235942108]
# Within radius count for 01119011500: 0
# Distances list for 01043965401: [1.5133593823699671]
# Within radius count for 01043965401: 1
# Distances list for 01003011503: [1.9242173374584728, 1.6812904085164764, 0.6595662012295602, 0.6374065617793587, 1.6783630060779222]
# Within radius count for 01003011503: 5
# Distances list for 01051030101: [4.97741312931316]
# Within radius count for 01051030101: 0
# Distances list for 01051030801: [0.729240066221712, 1.3869690669960542, 1.5259156424443214]
# Within radius count for 01051030801: 3
# Distances list for 01055001300: [0.1910644914634815]
# Within radius count for 01055001300: 1
# Distances list for 01055001700: [1.4722508197279407]
# Within radius count for 01055001700: 1
# Distances list for 01055000400: [0.999857085284812]
# Within radius count for 01055000400: 1
# Distances list for 01101003303: [0.6091601480949789]
# Within radius count for 01101003303: 1
# Distances list for 01055001100: [1.6275539535742543]
# Within radius count for 01055001100: 1
# Distances list for 01113030402: [0.6843751359801856, 0.6764276952047574]
# Within radius count for 01113030402: 2
# Distances list for 01107050000: [5.27321187129407]
# Within radius count for 01107050000: 0
# Distances list for 01107050100: [2.689119189154038]
# Within radius count for 01107050100: 0
# Distances list for 01127020100: [2.936430181020004]
# Within radius count for 01127020100: 0
# Distances list for 01083020103: [0.9474901734552739]
# Within radius count for 01083020103: 1
# Distances list for 01083021201: [1.0337810540961287, 1.198242031057493]
# Within radius count for 01083021201: 2
# Distances list for 01127020900: [5.033862958794847]
# Within radius count for 01127020900: 0
# Distances list for 01127020200: [3.5345991100650287]
# Within radius count for 01127020200: 0
# Distances list for 01067030500: [1.586138986098697, 0.8275380240784058]
# Within radius count for 01067030500: 2
# Distances list for 01067030200: [0.4974813471319203, 0.5796876882508919, 0.6239240954398081]
# Within radius count for 01067030200: 3
# Distances list for 01003011419: [14.417872770260917, 14.39763902919234, 14.147881226552421, 14.280929504620334, 14.281484371298372, 14.39763902919234]
# Within radius count for 01003011419: 0
# Distances list for 01003011603: [1.4042187022903698]
# Within radius count for 01003011603: 1
# Distances list for 01003011409: [1.5464449985015973]
# Within radius count for 01003011409: 1
# Distances list for 01003011414: [2.6090877958230707]
# Within radius count for 01003011414: 0
# Distances list for 01015002503: [1.6087842124830205, 1.8874243183490038]
# Within radius count for 01015002503: 2
# Distances list for 01097003711: [1.180429928308445]
# Within radius count for 01097003711: 1
# Distances list for 01097003409: [1.1179131945569918]
# Within radius count for 01097003409: 1
# Distances list for 01089011025: [0.7136190952564998]
# Within radius count for 01089011025: 1
# Distances list for 01119011301: [6.993321832201371]
# Within radius count for 01119011301: 1
# Distances list for 01125011902: [0.3270500993559757]
# Within radius count for 01125011902: 1
# Distances list for 01073005103: [0.39318724043287584]
# Within radius count for 01073005103: 1
# Distances list for 01073012905: [1.0030634306919748, 0.8858872998656437, 1.095975090330639, 0.9869937615195084, 1.2533728485018336]
# Within radius count for 01073012905: 5
# Distances list for 01001020501: [0.8899140192222642]
# Within radius count for 01001020501: 1
# Distances list for 01073004901: [0.2703288414010268, 0.19998560278487262, 0.22145665809891796]
# Within radius count for 01073004901: 3
# Distances list for 01073011108: [1.0893629634630126, 0.3392625074690088, 0.7771142602340342, 0.8598870788458337, 0.2530870568503435]
# Within radius count for 01073011108: 5
# Distances list for 01079979600: [1.3917032958157254]
# Within radius count for 01079979600: 1
# Distances list for 01079979400: [1.2394282628633526, 1.1297176884230076, 1.126569218885918, 1.13784935813497]
# Within radius count for 01079979400: 4
# Distances list for 01033020705: [1.4786089265276]
# Within radius count for 01033020705: 1
# Distances list for 01073012914: [0.48634732444855744]
# Within radius count for 01073012914: 1
# Distances list for 01073012910: [0.9686498212341376]
# Within radius count for 01073012910: 1
# Distances list for 01073012911: [1.2873004253082794, 0.9342715168695116]
# Within radius count for 01073012911: 2
# Distances list for 01073012802: [0.5040286836562067]
# Within radius count for 01073012802: 1
# Distances list for 01073012913: [0.7458315779740925, 0.8967744741281043]
# Within radius count for 01073012913: 2
# Distances list for 01015002104: [1.355501303285921, 0.84401748100232]
# Within radius count for 01015002104: 2
# Distances list for 01093964401: [4.2100767354684026]
# Within radius count for 01093964401: 1
# Distances list for 01077010901: [0.9666923599732135, 0.8221695794071614, 0.8076055132046759, 0.8293037956721097, 0.9143954443636088, 1.1629317074491095, 0.9767862712068606]
# Within radius count for 01077010901: 7
# Distances list for 01095030205: [2.958786351360785]
# Within radius count for 01095030205: 0
# Distances list for 01095030203: [4.205608451660836]
# Within radius count for 01095030203: 0
# Distances list for 01095031001: [1.2072151002047278]
# Within radius count for 01095031001: 1
# Distances list for 01029959800: [4.460736635093896]
# Within radius count for 01029959800: 1
# Distances list for 01029959600: [3.914909119224845, 3.7966797234608536]
# Within radius count for 01029959600: 0
# Distances list for 01073014209: [0.4874462739447325]
# Within radius count for 01073014209: 1
# Distances list for 01073002701: [0.19216219987631794, 0.259244429110527, 0.12940864189453058, 0.2698852023010774, 0.1948500251558409, 0.4440563247844058, 0.19339197274943126, 0.2647350311165504, 0.23422673853311257, 0.11813561097473643, 0.20882154667709987, 0.1697503972725016]
# Within radius count for 01073002701: 12
# Distances list for 01073012918: [0.4499474151818026]
# Within radius count for 01073012918: 1
# Distances list for 01073011116: [2.2530830218955926]
# Within radius count for 01073011116: 0
# Distances list for 01073012916: [0.5350229010416414, 1.041191616644169]
# Within radius count for 01073012916: 2
# Distances list for 01101005611: [1.662549366257442]
# Within radius count for 01101005611: 1
# Distances list for 01133965502: [1.8072249944200072]
# Within radius count for 01133965502: 1
# Distances list for 01133965503: [7.283026290666482, 7.423821794618639]
# Within radius count for 01133965503: 0
# Distances list for 01073014408: [0.47929060858588124, 0.27388398227224015]
# Within radius count for 01073014408: 2
# Distances list for 01073011301: [4.778968254378954]
# Within radius count for 01073011301: 0
# Distances list for 01121011302: [2.2790343219259683]
# Within radius count for 01121011302: 1
# Distances list for 01049960303: [1.6360785435825937, 1.4454039677574957, 1.3001347527097, 0.766199835214372]
# Within radius count for 01049960303: 4
# Distances list for 01103005601: [5.372806627701071]
# Within radius count for 01103005601: 0
# Distances list for 01073011805: [1.109625001966245]
# Within radius count for 01073011805: 1
# Distances list for 01123962100: [1.2443629252188366]
# Within radius count for 01123962100: 1
# Distances list for 01079979201: [4.4297248903096875, 1.7579928521077142]
# Within radius count for 01079979201: 1
# Distances list for 01009050701: [6.784265285667387]
# Within radius count for 01009050701: 0
# Distances list for 01009050301: [2.6394599444699467]
# Within radius count for 01009050301: 1
# Distances list for 01009050501: [1.8224494892773806, 1.5837291125606008]
# Within radius count for 01009050501: 2
# Distances list for 01093964500: [3.2015906890818018]
# Within radius count for 01093964500: 1
# Distances list for 01073012920: [0.34137653030038334]
# Within radius count for 01073012920: 1
# Distances list for 01073011003: [0.02254797830046772, 0.1143503314537011, 0.11306353163554031]
# Within radius count for 01073011003: 3
# Distances list for 01073011401: [0.6601197543567949, 1.0335747416062935, 0.9062348171068428]
# Within radius count for 01073011401: 3
# Distances list for 01051030500: [0.377354256694873, 1.7464295457534618]
# Within radius count for 01051030500: 2
# Distances list for 01019955701: [5.1094144261823216]
# Within radius count for 01019955701: 0
# Distances list for 01101005609: [1.6407584818499101, 1.7686594179478008]
# Within radius count for 01101005609: 2
# Distances list for 01039962100: [1.7315167615202913, 1.738672628285099]
# Within radius count for 01039962100: 2
# Distances list for 01039961700: [2.211948956411135]
# Within radius count for 01039961700: 1
# Distances list for 01081041101: [0.4338063401757644, 1.2303638055129569, 0.43439567106379273]
# Within radius count for 01081041101: 3
# Distances list for 01081040401: [0.465827366261838]
# Within radius count for 01081040401: 1
# Distances list for 01081040201: [0.44459513079110224, 0.508853178421984, 0.03328721176570257]
# Within radius count for 01081040201: 3
# Distances list for 01081040903: [0.19355388906042406, 0.17620993287599598]
# Within radius count for 01081040903: 2
# Distances list for 01095030701: [2.925653667469966, 2.807538954223046, 1.1020591672660374]
# Within radius count for 01095030701: 3
# Distances list for 01095030401: [2.3166664817547535, 2.6139775504649747]
# Within radius count for 01095030401: 2
# Distances list for 01095030903: [1.1821587205499406, 1.1415536056224223]
# Within radius count for 01095030903: 2
# Distances list for 01021060101: [1.6199909218673725, 2.9486137978390206, 1.7548385411963616, 1.785230551499814, 1.7807835830161864]
# Within radius count for 01021060101: 5
# Distances list for 01021060500: [1.0715594321724435]
# Within radius count for 01021060500: 1
# Distances list for 01021060401: [2.453637206758707, 2.4364929394196464, 2.5706587251807247]
# Within radius count for 01021060401: 0
# Distances list for 01013952700: [4.079372490160365, 4.2641999680673655, 4.259490453649871, 4.260425990004542, 4.2382647101190285]
# Within radius count for 01013952700: 5
# Distances list for 01027958900: [5.359065682677373, 5.347956740653933]
# Within radius count for 01027958900: 0
# Distances list for 01097003301: [0.7185779413001979, 0.7025387098389292]
# Within radius count for 01097003301: 2
# Distances list for 01097006402: [0.766839995028815]
# Within radius count for 01097006402: 1
# Distances list for 01111000300: [2.422129717470079, 2.5316236668023575]
# Within radius count for 01111000300: 0
# Distances list for 01111000400: [4.407449971068642]
# Within radius count for 01111000400: 1
# Distances list for 01111000500: [2.955952321776517]
# Within radius count for 01111000500: 1
# Distances list for 01117030317: [0.7712478648708626]
# Within radius count for 01117030317: 1
# Distances list for 01081040700: [0.6499991790356178]
# Within radius count for 01081040700: 1
# Distances list for 01081041300: [0.7910288384898032]
# Within radius count for 01081041300: 1
# Distances list for 01097006802: [1.2374488818638725, 1.2635293504194678]
# Within radius count for 01097006802: 2
# Distances list for 01097000200: [0.5200278389798322, 0.4192689211000207, 0.41443597830397816, 0.42688389889549366, 0.5463954517831502, 0.427644973350287, 0.4260471793745503, 0.5555671393369475, 0.35910820730972987, 0.4115050940476737, 0.33949375126270065, 0.4179385914660039, 0.43367821040492016]
# Within radius count for 01097000200: 13
# Distances list for 01097000600: [0.4774037699559613, 0.6554792395554659, 0.7499295450339818]
# Within radius count for 01097000600: 3
# Distances list for 01097005400: [0.3850879004631597, 1.1890100940114012, 0.9741923329209853, 0.32748452785697746]
# Within radius count for 01097005400: 4
# Distances list for 01081041400: [1.2557230047713295]
# Within radius count for 01081041400: 1
# Distances list for 01081041600: [0.9041150672991509, 0.930202875243626, 1.0574998762972116, 0.8204155861802843, 1.1238822350151252]
# Within radius count for 01081041600: 5
# Distances list for 01097003710: [1.1152007440386769]
# Within radius count for 01097003710: 1
# Distances list for 01097002501: [0.29664416639393626]
# Within radius count for 01097002501: 1
# Distances list for 01097003302: [0.37108055720281546, 0.38941443151632654, 0.4477560763297864, 0.465866635624376, 0.9506493973213035, 0.3806084201046804, 0.9505414987186509]
# Within radius count for 01097003302: 7
# Distances list for 01097002600: [0.7591316277597038]
# Within radius count for 01097002600: 1
# Distances list for 01097002700: [0.6734192589965594, 0.7087194089272089, 0.3938322838632694, 0.6846292895294266]
# Within radius count for 01097002700: 4
# Distances list for 01117030315: [1.854590400894466, 0.9459646267185583, 0.7297478190559155, 2.012807807055112, 0.8623551409598421, 2.32249894597248, 0.544349261248346]
# Within radius count for 01117030315: 5
# Distances list for 01117030607: [1.5123528573907732]
# Within radius count for 01117030607: 1
# Distances list for 01117030304: [0.992134730736698]
# Within radius count for 01117030304: 1
# Distances list for 01117030330: [1.5490470272407268, 1.1592040188288644, 1.209667156554921, 1.3401914883749602, 1.528473165375043, 1.2783377612459363]
# Within radius count for 01117030330: 6
# Distances list for 01117030306: [0.34517477572952093, 1.0387828103656755]
# Within radius count for 01117030306: 2
# Distances list for 01097000902: [0.31516330996544845]
# Within radius count for 01097000902: 1
# Distances list for 01097001001: [0.2888483285082259]
# Within radius count for 01097001001: 1
# Distances list for 01097002800: [0.4619879605870248, 0.42998135689424744]
# Within radius count for 01097002800: 2
# Distances list for 01073014410: [1.0086980346508636, 0.7272046515673074, 0.5242179738702507, 0.5447694605039122, 0.996212486944077, 0.8728442751295542, 1.1014296094578522, 1.0173127534238504, 0.8358480107290835]
# Within radius count for 01073014410: 9
# Distances list for 01003011501: [1.824528749874168, 1.390034703330479, 0.881124493594126, 0.5796651091057987]
# Within radius count for 01003011501: 4
# Distances list for 01069040302: [1.1295756576042397]
# Within radius count for 01069040302: 1
# Distances list for 01003011201: [0.6509598813127208, 1.2941767936236228, 1.2874230562835443, 0.5748688313226231, 1.1212978894964813, 0.5336449328698132, 0.5362308383667884, 1.27680574448662, 0.5881473482389845, 0.5299946307311804, 1.2648545662703436, 1.0124179034233722, 1.4366525115544388, 1.2610790585267402, 1.3609734903819928, 0.9541217533749976]
# Within radius count for 01003011201: 16
# Distances list for 01003010800: [0.6038580229101074, 0.644653807792336, 2.5495915459896183, 2.2329752914015644]
# Within radius count for 01003010800: 2
# Distances list for 01003010704: [1.2642238864452198]
# Within radius count for 01003010704: 1
# Distances list for 01033020802: [3.7284364817418973]
# Within radius count for 01033020802: 0
# Distances list for 01033021000: [3.2485058838934786]
# Within radius count for 01033021000: 0
# Distances list for 01033020100: [0.9349071589407132]
# Within radius count for 01033020100: 1
# Distances list for 01095030801: [2.629439034783608, 2.395767069122762, 2.63448967157246, 2.2816642744874933, 2.5501848216301117, 2.0300027804350447, 2.496640605642493, 2.5558233157129413]
# Within radius count for 01095030801: 8
# Distances list for 01043964400: [2.0881801443718033]
# Within radius count for 01043964400: 1
# Distances list for 01043964100: [2.5610142658013353]
# Within radius count for 01043964100: 1
# Distances list for 01043964700: [2.8070741146193456]
# Within radius count for 01043964700: 1
# Distances list for 01043965300: [1.7658857219017807, 1.7314123333279186]
# Within radius count for 01043965300: 2
# Distances list for 01095031200: [1.8379423860211366, 1.9559150435819548, 1.4467196271913714, 1.8207703871932432, 1.1266553458750401, 1.8505402833101188]
# Within radius count for 01095031200: 6
# Distances list for 01055010401: [0.5035694363213704, 0.7316032192739019, 0.5853683385566547, 0.5924112763320096, 0.6229025116873754, 0.5111287522313434]
# Within radius count for 01055010401: 6
# Distances list for 01039962500: [1.2018215809300596]
# Within radius count for 01039962500: 1
# Distances list for 01039962000: [1.9001908107067544]
# Within radius count for 01039962000: 1
# Distances list for 01017954200: [2.1442039676978197]
# Within radius count for 01017954200: 1
# Distances list for 01017954300: [5.384211727729386, 6.230111439852065]
# Within radius count for 01017954300: 0
# Distances list for 01017954700: [1.8201608817910697]
# Within radius count for 01017954700: 1
# Distances list for 01125011600: [0.7551705475508776, 0.9206779221523261, 0.8548425424071631, 0.8420775887914519, 0.7841699996404854, 0.8042402037068453, 0.892066837665456, 0.5723470422553535, 0.9848278969926537, 0.735638649406799, 1.0433707764378561, 1.073344989947715, 0.8924969295283479, 0.7581409401274113]
# Within radius count for 01125011600: 14
# Distances list for 01023956800: [1.4865977089565068, 1.5800594908793582]
# Within radius count for 01023956800: 2
# Distances list for 01023956900: [4.455072422446368]
# Within radius count for 01023956900: 1
# Distances list for 01125012304: [0.706447468507548, 0.6860159415584097, 0.6303648764529242]
# Within radius count for 01125012304: 3
# Distances list for 01117030348: [0.9872465077069154, 0.5999253275893232, 0.45256737971944017]
# Within radius count for 01117030348: 3
# Distances list for 01117030612: [1.9294030202665908]
# Within radius count for 01117030612: 1
# Distances list for 01117030218: [2.632421721847145]
# Within radius count for 01117030218: 0
# Distances list for 01117030352: [2.1445258541984438]
# Within radius count for 01117030352: 0
# Distances list for 01109189001: [2.6415446819608506]
# Within radius count for 01109189001: 1
# Distances list for 01109189101: [0.9707341665525768, 0.8429427663713366]
# Within radius count for 01109189101: 2
# Distances list for 01097005500: [0.5027709413741164, 0.4378392608466852]
# Within radius count for 01097005500: 2
# Distances list for 01097007300: [1.2782664016373517, 1.2018213755602454]
# Within radius count for 01097007300: 2
# Distances list for 01097001200: [1.0532566912463608]
# Within radius count for 01097001200: 1
# Distances list for 01097007103: [1.9275043905613487]
# Within radius count for 01097007103: 1
# Distances list for 01097003000: [0.7187176168370852]
# Within radius count for 01097003000: 1
# Distances list for 01015001700: [1.0392527442367328]
# Within radius count for 01015001700: 1
# Distances list for 01015000200: [0.8922678751306676]
# Within radius count for 01015000200: 1
# Distances list for 01031010900: [2.271629372742333, 2.291890041335103, 2.166716824009618]
# Within radius count for 01031010900: 3
# Distances list for 01031010500: [5.224003840164432]
# Within radius count for 01031010500: 1
# Distances list for 01031011000: [1.5078066557793008, 0.7388692000164861]
# Within radius count for 01031011000: 2
# Distances list for 01031010600: [3.881915525193084]
# Within radius count for 01031010600: 1
# Distances list for 01113030200: [0.45708657661981583, 0.5029831559268623]
# Within radius count for 01113030200: 2
# Distances list for 01031011100: [0.8374351136357205, 0.8363435824927218, 0.5293801540099954]
# Within radius count for 01031011100: 3
# Distances list for 01113030700: [0.10724744702908538, 0.665712740150554]
# Within radius count for 01113030700: 2
# Distances list for 01083020500: [0.8548657670639321]
# Within radius count for 01083020500: 1
# Distances list for 01073011109: [0.4982620833870336, 2.3906344513490074]
# Within radius count for 01073011109: 1
# Distances list for 01125010406: [0.9227694346618311, 0.8414345567365141, 0.8269122806784046, 1.1588801479039894, 0.8180349011993687]
# Within radius count for 01125010406: 5
# Distances list for 01125010204: [1.6178094589053675, 1.5804834952980409]
# Within radius count for 01125010204: 2
# Distances list for 01125012403: [0.8801473875665446]
# Within radius count for 01125012403: 1
# Distances list for 01125010407: [0.9161622944325674]
# Within radius count for 01125010407: 1
# Distances list for 01125010403: [1.8669744542228452, 0.594102790099454, 0.5877565864946681]
# Within radius count for 01125010403: 3
# Distances list for 01125011200: [0.43595447634607165, 0.7689415913098775, 0.7923149372729267]
# Within radius count for 01125011200: 3
# Distances list for 01065040000: [6.268780374124767]
# Within radius count for 01065040000: 0
# Distances list for 01049961100: [1.850920330794145, 1.908144110590004, 2.0100278115145978]
# Within radius count for 01049961100: 3
# Distances list for 01049961400: [3.9366307604684003]
# Within radius count for 01049961400: 1
# Distances list for 01071950800: [0.5179182692148332, 0.7045475658796012, 0.7206104148400608, 0.7377957985533673, 0.13937176542565527, 0.6460822231912131, 0.44949038168928873]
# Within radius count for 01071950800: 7
# Distances list for 01061050400: [3.174240122907938]
# Within radius count for 01061050400: 0
# Distances list for 01061050500: [1.3303121702362786, 1.1222950972411696]
# Within radius count for 01061050500: 2
# Distances list for 01073010802: [1.3672560209754852, 0.6176282074628779, 1.3882429370255287, 1.296560272331164, 0.6193731518679921, 0.6240546086028036, 0.8549628064852349, 0.6368157769984915]
# Within radius count for 01073010802: 8
# Distances list for 01073012103: [2.8551853810707617, 1.7555094794575985]
# Within radius count for 01073012103: 1
# Distances list for 01073014104: [2.6848587363952654]
# Within radius count for 01073014104: 0
# Distances list for 01073005600: [0.4837720821106855, 0.2237650734594985, 0.47667176181039356, 0.6613427105693745, 0.44945529309118304]
# Within radius count for 01073005600: 5
# Distances list for 01073011205: [1.010100529473098]
# Within radius count for 01073011205: 1
# Distances list for 01089001302: [0.603059586841245]
# Within radius count for 01089001302: 1
# Distances list for 01089003100: [0.06247283088969033, 0.29820436445674936, 0.19474319736312762, 0.12284662470685982, 0.1899587731567692, 0.40485250694688835, 0.24991505024923422, 0.40532464289265324, 0.38954913388085927, 0.12123179716502572, 0.24450307434216711, 0.49440228145117354, 0.11642005656191887, 0.46193152696485285, 0.4728692726909685, 0.08322823968241695, 0.20618907142082693, 0.1387797871631886, 0.23126087120895714]
# Within radius count for 01089003100: 19
# Distances list for 01015000600: [1.0225485631767688]
# Within radius count for 01015000600: 1
# Distances list for 01015001000: [2.096812650561969, 0.36723867631800927, 0.26469905818652933]
# Within radius count for 01015001000: 2
# Distances list for 01015002102: [2.2289354878776395]
# Within radius count for 01015002102: 0
# Distances list for 01015000700: [1.6882404558791555]
# Within radius count for 01015000700: 1
# Distances list for 01015002300: [3.6591427434914965, 3.4514470297829574]
# Within radius count for 01015002300: 0
# Distances list for 01073013902: [0.6597078834246033, 0.6565958587971437]
# Within radius count for 01073013902: 2
# Distances list for 01073014105: [1.207437901219883]
# Within radius count for 01073014105: 1
# Distances list for 01073000800: [1.0725569360674094, 1.1655089474640639]
# Within radius count for 01073000800: 2
# Distances list for 01073001902: [0.8332120335755395]
# Within radius count for 01073001902: 1
# Distances list for 01073003300: [0.38677879668128906]
# Within radius count for 01073003300: 1
# Distances list for 01073003900: [0.37657430920814916]
# Within radius count for 01073003900: 1
# Distances list for 01041963800: [7.739431368400554]
# Within radius count for 01041963800: 1
# Distances list for 01041963700: [2.2535944203346037, 2.1008658819669788]
# Within radius count for 01041963700: 0
# Distances list for 01045020100: [4.728393349197195]
# Within radius count for 01045020100: 1
# Distances list for 01073004701: [0.23115186166898502]
# Within radius count for 01073004701: 1
# Distances list for 01073005200: [0.41015155291896477]
# Within radius count for 01073005200: 1
# Distances list for 01073005800: [0.6692841952792457, 0.7278122882985272]
# Within radius count for 01073005800: 2
# Distances list for 01089002801: [0.7274447206596037, 0.7371931259780031, 0.7525298048216517]
# Within radius count for 01089002801: 3
# Distances list for 01101005402: [0.5246251742389042, 0.5212536250608617]
# Within radius count for 01101005402: 2
# Distances list for 01101005800: [1.597194979813739]
# Within radius count for 01101005800: 1
# Distances list for 01101000100: [0.11628585907262017, 0.13153278585359482, 0.5980992534667, 0.32283093435765287, 0.4362969856388396, 0.12766326085957844, 0.1191817564578556, 0.34444560910831906, 0.3879307773107372, 0.21108745034907617, 0.28449471272755034]
# Within radius count for 01101000100: 11
# Distances list for 01101000200: [0.37941938035401185]
# Within radius count for 01101000200: 1
# Distances list for 01101000600: [0.39626239976398847]
# Within radius count for 01101000600: 1
# Distances list for 01121010201: [2.657797705300609, 2.683964916032331, 2.7051360391577397]
# Within radius count for 01121010201: 0
# Distances list for 01101001600: [0.2909501229277608]
# Within radius count for 01101001600: 1
# Distances list for 01053970300: [7.52071724042404]
# Within radius count for 01053970300: 1
# Distances list for 01053970700: [3.0739130678175197, 3.4068832467840915, 3.4068832467840915]
# Within radius count for 01053970700: 3
# Distances list for 01053970200: [0.6157527922327876, 0.4362333420134345, 0.7876199429833107]
# Within radius count for 01053970200: 3
# Distances list for 01053970100: [3.83206574126856, 5.235518738204341, 3.681685902537158, 4.636176402325506]
# Within radius count for 01053970100: 4
# Distances list for 01101001700: [0.8389556115490479]
# Within radius count for 01101001700: 1
# Distances list for 01101001800: [0.7136774399356982]
# Within radius count for 01101001800: 1
# Distances list for 01101002000: [0.5707058871351621, 0.8582080880761288]
# Within radius count for 01101002000: 2
# Distances list for 01001020600: [0.4582840641035245]
# Within radius count for 01001020600: 1
# Distances list for 01001020700: [2.4260462826074845, 2.3265217167016345]
# Within radius count for 01001020700: 0
# Distances list for 01045020500: [1.3510469119848112, 1.4235384544993048]
# Within radius count for 01045020500: 2
# Distances list for 01027959000: [3.485147818299602, 3.6109777450412035]
# Within radius count for 01027959000: 0
# Distances list for 01019956000: [1.8292141319916526]
# Within radius count for 01019956000: 1
# Distances list for 01123962400: [6.029662225882176, 5.9160752755478665, 5.924370985845269]
# Within radius count for 01123962400: 0
# Distances list for 01123962000: [4.618580441192628]
# Within radius count for 01123962000: 1
# Distances list for 01103000300: [0.33525463951023327, 0.1914401823530731, 0.6542822744268375]
# Within radius count for 01103000300: 3
# Distances list for 01103000400: [0.42643693255705967, 0.39950579912670126, 0.2766329452809374, 0.5444282698045133, 1.6910976404727152, 0.5019747544334777, 0.3963500750559003]
# Within radius count for 01103000400: 7
# Distances list for 01103005303: [0.17365697467543023, 0.7274530449199081, 0.17636066930564837]
# Within radius count for 01103005303: 3
# Distances list for 01033020300: [0.12388183111751427]
# Within radius count for 01033020300: 1
# Distances list for 01043964201: [3.047229588693499, 4.499723740711311]
# Within radius count for 01043964201: 2
# Distances list for 01043964901: [2.1659972760703625]
# Within radius count for 01043964901: 1
# Distances list for 01033020500: [1.3417675933857747, 1.41983961077129]
# Within radius count for 01033020500: 2
# Distances list for 01109188800: [9.931856742883303]
# Within radius count for 01109188800: 0
# Distances list for 01109189300: [2.036482992572199, 2.4085637647985383]
# Within radius count for 01109189300: 2
# Distances list for 01073005905: [0.5823276269260713]
# Within radius count for 01073005905: 1
# Distances list for 01073010001: [0.2257032429834488]
# Within radius count for 01073010001: 1
# Distances list for 01073010002: [0.766963488636291]
# Within radius count for 01073010002: 1
# Distances list for 01073010200: [0.360456753301013, 0.5594126383240468, 0.557508674810078, 0.40915742385650256]
# Within radius count for 01073010200: 4
# Distances list for 01073010603: [0.7144422450206596, 0.57905634735195]
# Within radius count for 01073010603: 2
# Distances list for 01073010703: [0.5763785769261583, 0.5751630466154611, 0.580894487068117, 0.3519790051324742, 0.24470498922149828, 0.3503338360112102]
# Within radius count for 01073010703: 6
# Distances list for 01015000800: [0.793090095739574, 0.8070264329969062, 0.7438489666654327, 0.7181499935060225, 0.4677572225800466, 0.8963452267273417]
# Within radius count for 01015000800: 6
# Distances list for 01097003502: [0.8960384340246378]
# Within radius count for 01097003502: 1
# Distances list for 01097005200: [0.4654450058994937]
# Within radius count for 01097005200: 1
# Distances list for 01097002900: [0.6852112078167831]
# Within radius count for 01097002900: 1
# Distances list for 01097003606: [0.6676301502382593, 0.4887180175537127, 0.5645829038908079, 0.6885130139917962]
# Within radius count for 01097003606: 4
# Distances list for 01097006403: [1.688822994767261, 1.9091386977419469]
# Within radius count for 01097006403: 2
# Distances list for 01073010705: [0.5006919295379102]
# Within radius count for 01073010705: 1
# Distances list for 01073010706: [0.8016692149535829, 0.5965104152412367]
# Within radius count for 01073010706: 2
# Distances list for 01073010801: [0.7032866656800246, 0.7107859482312199, 0.8883346957631626, 0.6958849980249555, 0.7163918127693604, 0.7018346799212154, 0.7246736021773503, 0.7800861453807302, 1.0141241899870281]
# Within radius count for 01073010801: 9
# Distances list for 01055010601: [0.38695771424537934]
# Within radius count for 01055010601: 1
# Distances list for 01055011001: [2.6012847874294]
# Within radius count for 01055011001: 1
# Distances list for 01097003100: [0.709651352848223]
# Within radius count for 01097003100: 1
# Distances list for 01103005108: [0.6277116138048092, 0.5759809265509155, 0.993435412135129]
# Within radius count for 01103005108: 3
# Distances list for 01097003704: [0.520076453989648, 0.5160111646359732, 0.6871776460754385]
# Within radius count for 01097003704: 3
# Distances list for 01097003705: [0.6266746672301888]
# Within radius count for 01097003705: 1
# Distances list for 01097003706: [0.7808126820694792]
# Within radius count for 01097003706: 1
# Distances list for 01097003707: [0.6571549715005893, 0.7692914980388761]
# Within radius count for 01097003707: 2
# Distances list for 01073003700: [0.6443196077968868]
# Within radius count for 01073003700: 1
# Distances list for 01073011704: [3.457202597847178]
# Within radius count for 01073011704: 0
# Distances list for 01103005106: [1.4414758488081962, 1.1686433446438458]
# Within radius count for 01103005106: 2
# Distances list for 01073011804: [0.687153165488377]
# Within radius count for 01073011804: 1
# Distances list for 01073000100: [1.5924652542677697, 1.3528897930686714, 1.3617165816614027]
# Within radius count for 01073000100: 3
# Distances list for 01073000300: [0.24600528089867196]
# Within radius count for 01073000300: 1
# Distances list for 01073012401: [0.4702500023640148]
# Within radius count for 01073012401: 1
# Distances list for 01073012402: [0.9924991953580515, 0.9910216044804108, 0.6573064123577622]
# Within radius count for 01073012402: 3
# Distances list for 01005950900: [1.4678801548205422, 1.7115008229517958]
# Within radius count for 01005950900: 2
# Distances list for 01005950600: [7.090771653062822]
# Within radius count for 01005950600: 1
# Distances list for 01005950200: [3.173928335503619, 3.050070437902617]
# Within radius count for 01005950200: 2
# Distances list for 01005950300: [0.8438156213880064]
# Within radius count for 01005950300: 1
# Distances list for 01005950700: [7.76457950222731]
# Within radius count for 01005950700: 1
# Distances list for 01005950800: [2.6569197793578025, 2.65793271468563]
# Within radius count for 01005950800: 2
# Distances list for 01073000400: [1.1036716152564436]
# Within radius count for 01073000400: 1
# Distances list for 01073012908: [0.36111391152633876, 0.4272588754414256]
# Within radius count for 01073012908: 2
# Distances list for 01095030402: [2.5671946983113014]
# Within radius count for 01095030402: 1
# Distances list for 01121010900: [0.29349955334403577, 0.2834973349423127, 0.3505631851439811]
# Within radius count for 01121010900: 3
# Distances list for 01091973300: [6.378352541922068]
# Within radius count for 01091973300: 1
# Distances list for 01091973100: [4.826673188399865]
# Within radius count for 01091973100: 1
# Distances list for 01121011800: [0.6649818964406773, 0.5589994917805334, 0.19337274289406636, 0.4152293716417793]
# Within radius count for 01121011800: 4
# Distances list for 01101005410: [0.8370787516641521]
# Within radius count for 01101005410: 1
# Distances list for 01089011013: [0.8805742583237084]
# Within radius count for 01089011013: 1
# Distances list for 01115040104: [1.7608404362126864, 1.2303873785931945]
# Within radius count for 01115040104: 2
# Distances list for 01115040401: [4.461496445295515]
# Within radius count for 01115040401: 0
# Distances list for 01083020202: [0.7001432089865836]
# Within radius count for 01083020202: 1
# Distances list for 01101005407: [1.2492653653988757, 0.7468952769976921, 0.8759640102701728, 0.6261219200725332]
# Within radius count for 01101005407: 4
# Distances list for 01057020200: [3.6311001499554614, 3.6382197735363753]
# Within radius count for 01057020200: 2
# Distances list for 01117030407: [2.2600002623900903]
# Within radius count for 01117030407: 0
# Distances list for 01057020300: [7.252174214859522, 5.616345285510375, 5.698177595239845]
# Within radius count for 01057020300: 3
# Distances list for 01117030341: [0.38190487661518946, 0.4617508172718152]
# Within radius count for 01117030341: 2
# Distances list for 01117030502: [4.471179857842732]
# Within radius count for 01117030502: 0
# Distances list for 01117030703: [1.6653585870723666, 1.2583125187829434]
# Within radius count for 01117030703: 2
# Distances list for 01117030406: [1.7207881653542023]
# Within radius count for 01117030406: 1
# Distances list for 01009050200: [2.287621081220683]
# Within radius count for 01009050200: 0
# Distances list for 01129043900: [1.7378940606346376]
# Within radius count for 01129043900: 1
# Distances list for 01089001500: [0.49251363332077763]
# Within radius count for 01089001500: 1
# Distances list for 01089002000: [0.23566768339998737]
# Within radius count for 01089002000: 1
# Distances list for 01047956400: [0.6594268655367179]
# Within radius count for 01047956400: 1
# Distances list for 01047956600: [0.5196171188898677]
# Within radius count for 01047956600: 1
# Distances list for 01083020600: [1.4960912039443193, 1.452076583626225, 1.3858578019379728]
# Within radius count for 01083020600: 3
# Distances list for 01083020900: [1.4492314559116573, 1.4960406908970874, 0.5255636352972214, 1.3713223433271093, 0.5740387462966251]
# Within radius count for 01083020900: 5
# Distances list for 01047956300: [1.4996744154971045, 1.8440095779736783]
# Within radius count for 01047956300: 2
# Distances list for 01069041700: [4.281083691875912]
# Within radius count for 01069041700: 0
# Distances list for 01089002600: [0.14118504511380625, 0.42405070643456816, 1.1037515860027047, 0.49745018090142334, 0.4676117208701902, 0.24062211683674856]
# Within radius count for 01089002600: 6
# Distances list for 01089002721: [0.9225946178799797]
# Within radius count for 01089002721: 1
# Distances list for 01077011602: [1.1674768805717683]
# Within radius count for 01077011602: 1
# Distances list for 01077010400: [1.2893323640255678]
# Within radius count for 01077010400: 1
# Distances list for 01077011300: [3.7487896236717018]
# Within radius count for 01077011300: 0
# Distances list for 01003011202: [1.6535900713152978, 1.3329762629144892, 1.1644450836212794, 1.3595507700893181, 1.3669773009976949]
# Within radius count for 01003011202: 5
# Distances list for 01025957800: [7.785990292364408, 7.800151717553586, 7.920390487222813]
# Within radius count for 01025957800: 3
# Distances list for 01069040400: [0.6448051472712593]
# Within radius count for 01069040400: 1
# Distances list for 01069040500: [0.7317046804786442, 0.644628827579457, 0.7470459982284203, 0.7845782266353191]
# Within radius count for 01069040500: 4
# Distances list for 01069040600: [0.564520383550678]
# Within radius count for 01069040600: 1
# Distances list for 01077011101: [1.0961947249573627]
# Within radius count for 01077011101: 1
# Distances list for 01077011802: [1.1198134758975289]
# Within radius count for 01077011802: 1
# Distances list for 01033020600: [1.1372454976953923]
# Within radius count for 01033020600: 1
# Distances list for 01087231700: [1.0223529736819255]
# Within radius count for 01087231700: 1
# Distances list for 01087232000: [0.17387789844539675, 0.3087405535346033]
# Within radius count for 01087232000: 2
# Distances list for 01087231500: [3.6519724736943693]
# Within radius count for 01087231500: 0
# Distances list for 02020001401: [0.2730432915525999, 0.35613468975591606]
# Within radius count for 02020001401: 2
# Distances list for 02020002713: [1.1187572586273156, 1.1505707392194078]
# Within radius count for 02020002713: 2
# Distances list for 02185000100: [2.262486562471932]
# Within radius count for 02185000100: 1
# Distances list for 02180000200: [6.499396229554622]
# Within radius count for 02180000200: 1
# Distances list for 02070000200: [7.780663947992702]
# Within radius count for 02070000200: 1
# Distances list for 02110000300: [2.9395771576068377, 2.9784823197476995, 2.850410289327339, 2.905994298081609]
# Within radius count for 02110000300: 4
# Distances list for 02110000200: [1.873358684983482]
# Within radius count for 02110000200: 1
# Distances list for 02170000800: [1.5647954726896676, 2.315359144332677, 1.5706535924364975, 0.9483949106815083]
# Within radius count for 02170000800: 4
# Distances list for 02220000200: [1.2417612683303467, 1.2002196985036127, 1.1795115585581861, 1.1920409645636343]
# Within radius count for 02220000200: 4
# Distances list for 02150000200: [0.7168350173770969]
# Within radius count for 02150000200: 1
# Distances list for 02060000100: [10.867988506405839]
# Within radius count for 02060000100: 0
# Distances list for 02188000200: [11.08602647386539]
# Within radius count for 02188000200: 0
# Distances list for 02020002302: [1.0312417296640999]
# Within radius count for 02020002302: 1
# Distances list for 02020002502: [0.9959141477124392]
# Within radius count for 02020002502: 1
# Distances list for 02020001900: [0.7204970854061459, 0.7204970854061459, 0.32634970633060234, 0.8177369861902447, 0.6211349930810074]
# Within radius count for 02020001900: 5
# Distances list for 02020002601: [0.8968203528105811]
# Within radius count for 02020002601: 1
# Distances list for 02020002000: [0.5014219256231185, 0.41437489580261594]
# Within radius count for 02020002000: 2
# Distances list for 02020001702: [0.6242763424607818]
# Within radius count for 02020001702: 1
# Distances list for 02020001731: [0.3275067509734899]
# Within radius count for 02020001731: 1
# Distances list for 02020001500: [0.5843868580537346, 0.3143938551735158]
# Within radius count for 02020001500: 2
# Distances list for 02063000300: [48.31705539515494]
# Within radius count for 02063000300: 0
# Distances list for 02020002712: [1.2739575234774903, 1.1491551728004668, 1.3106855012140148]
# Within radius count for 02020002712: 3
# Distances list for 02020002711: [1.05776635973207]
# Within radius count for 02020002711: 1
# Distances list for 02020001000: [0.5631775905739335]
# Within radius count for 02020001000: 1
# Distances list for 02020001100: [0.3608631326498957, 0.1437436838146228, 0.11527110335483966]
# Within radius count for 02020001100: 3
# Distances list for 02130000200: [1.49816392518441, 1.5169394537786298, 1.474780946606477]
# Within radius count for 02130000200: 3
# Distances list for 02275000300: [24.42581658520965]
# Within radius count for 02275000300: 0
# Distances list for 02195000200: [20.84476560533062, 21.02873582067452]
# Within radius count for 02195000200: 0
# Distances list for 02090000100: [0.2515225806478916, 0.1485559784290648, 0.2515225806478916, 0.09994238387737579]
# Within radius count for 02090000100: 4
# Distances list for 02090000300: [0.5378859212821122]
# Within radius count for 02090000300: 1
# Distances list for 02090000700: [0.26045876721459754, 0.4354811272040857, 0.42175901905776086]
# Within radius count for 02090000700: 3
# Distances list for 02090000500: [0.8380794789546391, 0.4918194887267908]
# Within radius count for 02090000500: 2
# Distances list for 02090000200: [0.28199859311241093]
# Within radius count for 02090000200: 1
# Distances list for 02090001000: [2.682119331382891]
# Within radius count for 02090001000: 0
# Distances list for 02090000800: [1.2480541736894102, 0.572308871634067]
# Within radius count for 02090000800: 2
# Distances list for 02122000600: [2.5403021194449837, 2.7151252907086962, 2.679984673991446]
# Within radius count for 02122000600: 3
# Distances list for 04019004067: [0.5238964257937345, 0.5446716547595826]
# Within radius count for 04019004067: 2
# Distances list for 04019003303: [0.5972570435103783, 0.458635103832459, 0.44466543838319383]
# Within radius count for 04019003303: 3
# Distances list for 04019004426: [0.4701467387106483, 0.499341556521145, 0.5481335025892511]
# Within radius count for 04019004426: 3
# Distances list for 04019004725: [0.6272711170182937, 0.8555027520861295]
# Within radius count for 04019004725: 2
# Distances list for 04015953901: [1.0486899819714925, 0.5511046268034969, 0.767894076322836]
# Within radius count for 04015953901: 3
# Distances list for 04015953001: [0.7589746575017111, 0.4189549365528754, 0.4248390188279687]
# Within radius count for 04015953001: 3
# Distances list for 04015952901: [0.3525463130919522]
# Within radius count for 04015952901: 1
# Distances list for 04015951503: [1.2574932687666196, 1.2574932687666196, 1.2574932687666196]
# Within radius count for 04015951503: 3
# Distances list for 04015953603: [0.46330330191308056, 0.7948975934175029]
# Within radius count for 04015953603: 2
# Distances list for 04021002004: [1.0153596950088486]
# Within radius count for 04021002004: 1
# Distances list for 04021001715: [0.9496947623645845, 1.0197583512190362]
# Within radius count for 04021001715: 2
# Distances list for 04021000320: [0.5170051352770234]
# Within radius count for 04021000320: 1
# Distances list for 04021000227: [0.38154055079074245]
# Within radius count for 04021000227: 1
# Distances list for 04019000501: [0.3298278957213394]
# Within radius count for 04019000501: 1
# Distances list for 04013093104: [0.8178636001435928]
# Within radius count for 04013093104: 1
# Distances list for 04013103205: [0.4994619610258721]
# Within radius count for 04013103205: 1
# Distances list for 04013116725: [0.7499969576835862, 0.7271961346301753]
# Within radius count for 04013116725: 2
# Distances list for 04013040506: [1.102167445164951]
# Within radius count for 04013040506: 1
# Distances list for 04013040507: [0.5931255074502647, 0.614352420034667, 0.5818724773137436, 0.44711210495572384, 0.4452726442559379, 0.4417127534418317, 0.8710253269628352, 0.6120652563191922]
# Within radius count for 04013040507: 8
# Distances list for 04013103207: [0.5823842694796539]
# Within radius count for 04013103207: 1
# Distances list for 04013103208: [0.5997678003343353]
# Within radius count for 04013103208: 1
# Distances list for 04013103209: [0.922305024211392, 0.9085684149054496, 0.966039922893542, 0.7111956713964691]
# Within radius count for 04013103209: 4
# Distances list for 04013318900: [0.6190496065959984]
# Within radius count for 04013318900: 1
# ...
# Distances list for 55025001501: [0.5761571380918376, 0.7091223281365783]
# Within radius count for 55025001501: 2
# Distances list for 55079020100: [0.30629582701994534, 0.4985410640061534, 0.5505670192064317, 0.5864369582271522]
# Within radius count for 55079020100: 4
# Distances list for 55079015700: [0.2518648526045436]
# Within radius count for 55079015700: 1
# Distances list for 55025002200: [0.5766946077450457, 0.5169232222847292]
# Within radius count for 55025002200: 2
# Distances list for 55079000400: [0.4168478089727555]
# Within radius count for 55079000400: 1
# Distances list for 55079000501: [0.28681157447890077, 0.28494682114570236]
# Within radius count for 55079000501: 2
# Distances list for 55079000700: [0.5186387190763938, 0.8268453888259027]
# Within radius count for 55079000700: 2
# Distances list for 55079019900: [0.3745915346279411, 0.2956195308765435]
# Within radius count for 55079019900: 2
# Distances list for 55079030100: [0.8612052494128593, 0.8678997028960461]
# Within radius count for 55079030100: 2
# Distances list for 55025000204: [0.5287455330840476, 0.510825274965058, 0.5333138194439113]
# Within radius count for 55025000204: 3
# Distances list for 55079091200: [0.2627683305555826, 0.1466423661260658, 0.19965265097392906, 0.16746194385661178]
# Within radius count for 55079091200: 4
# Distances list for 55079016900: [0.2972302083306128]
# Within radius count for 55079016900: 1
# Distances list for 55005000400: [5.068405080741905, 5.165218746873771]
# Within radius count for 55005000400: 2
# Distances list for 55005000500: [1.287270094674661, 1.6226362788788367, 1.4505838814712524]
# Within radius count for 55005000500: 3
# Distances list for 55005000200: [3.9958769864304067, 4.016795829860123, 3.9444424048516455]
# Within radius count for 55005000200: 3
# Distances list for 55079018300: [0.3331550034443057]
# Within radius count for 55079018300: 1
# Distances list for 55025012201: [1.4474055602410127, 1.4314299119147662]
# Within radius count for 55025012201: 2
# Distances list for 55025011301: [0.8985689599958089, 0.8387888857840347, 0.6779676419515747]
# Within radius count for 55025011301: 3
# Distances list for 55025012300: [1.7312841945265234, 1.2889006909227418]
# Within radius count for 55025012300: 2
# Distances list for 55025011600: [1.2462963247598915]
# Within radius count for 55025011600: 1
# Distances list for 55025012800: [0.9141898776296239]
# Within radius count for 55025012800: 1
# Distances list for 55025013100: [3.0203243202922287, 1.3229179209344013]
# Within radius count for 55025013100: 2
# Distances list for 55079005900: [0.15893422796762532]
# Within radius count for 55079005900: 1
# Distances list for 55079004400: [0.3418884123795764, 0.16404606511779238, 0.33892152973722844]
# Within radius count for 55079004400: 3
# Distances list for 55025000205: [1.024062029579673]
# Within radius count for 55025000205: 1
# Distances list for 55025010702: [2.55066416668824, 3.3581314933024817, 2.585084468712927, 2.729667631093607]
# Within radius count for 55025010702: 0
# Distances list for 55025001502: [0.8531798125221975, 1.3937676855255217]
# Within radius count for 55025001502: 2
# Distances list for 55025011900: [2.8721219708592094, 3.1380198661508105]
# Within radius count for 55025011900: 0
# Distances list for 55025011800: [2.50288206645776]
# Within radius count for 55025011800: 0
# Distances list for 55025001402: [1.057629493475448, 0.9962380618354791]
# Within radius count for 55025001402: 2
# Distances list for 55025012400: [2.253373530588006, 5.862374614371077]
# Within radius count for 55025012400: 0
# Distances list for 55133202800: [0.39157208775773894, 0.25838126569986725]
# Within radius count for 55133202800: 2
# Distances list for 55133202400: [0.5947766469390497]
# Within radius count for 55133202400: 1
# Distances list for 55133202700: [0.15599882142454816]
# Within radius count for 55133202700: 1
# Distances list for 55133203702: [1.137315660183132, 1.1755422801922015]
# Within radius count for 55133203702: 2
# Distances list for 55043961200: [5.070735967700046, 4.464525180282742]
# Within radius count for 55043961200: 0
# Distances list for 55043960300: [2.774570461636676, 2.4140344871679016, 2.817552360251479]
# Within radius count for 55043960300: 3
# Distances list for 55043960200: [3.224176428009619]
# Within radius count for 55043960200: 1
# Distances list for 55043960700: [0.4800793144908082, 0.26818081749317174, 0.31928621072464475, 0.4813286148274462]
# Within radius count for 55043960700: 4
# Distances list for 55043960800: [3.5535232831427526, 4.881694992784226]
# Within radius count for 55043960800: 2
# Distances list for 55043960100: [8.303435804837363]
# Within radius count for 55043960100: 1
# Distances list for 55043960500: [8.911952787704704]
# Within radius count for 55043960500: 1
# Distances list for 55043961100: [1.8972265320899508, 6.365884152496165, 6.350095992407718]
# Within radius count for 55043961100: 1
# Distances list for 55043960600: [8.61321052070421]
# Within radius count for 55043960600: 1
# Distances list for 56031959401: [8.7624945370615, 8.93271112062071, 8.760989317782144, 9.350150166625571]
# Within radius count for 56031959401: 4
# Distances list for 56011950300: [3.2621889701594533]
# Within radius count for 56011950300: 1
# Distances list for 56021001301: [0.5477717235637793, 0.5426227175879123, 0.6026766320384066]
# Within radius count for 56021001301: 3
# Distances list for 56021000601: [0.0592108513176923, 0.14697552578891296]
# Within radius count for 56021000601: 2
# Distances list for 56021000701: [0.41821358622330984]
# Within radius count for 56021000701: 1
# Distances list for 56015957800: [2.5759752905531, 2.504134787830271, 2.485779762049115, 2.546245193401762, 2.5759752905531]
# Within radius count for 56015957800: 5
# Distances list for 56035000103: [18.73440020434446, 18.704620778358002, 18.745319041159004, 18.63755756921869]
# Within radius count for 56035000103: 0
# Distances list for 56005000102: [15.832405665900895]
# Within radius count for 56005000102: 0
# Distances list for 56025001602: [0.12786368232531375, 0.8989084479303372]
# Within radius count for 56025001602: 2
# Distances list for 56037970903: [0.6193988023708852, 1.0334528239445526, 0.933833920638648, 1.15422358706796]
# Within radius count for 56037970903: 4
# Distances list for 56037970902: [1.6858960630569981]
# Within radius count for 56037970902: 1
# Distances list for 56037971100: [2.0841064245129535, 2.0851977275959386]
# Within radius count for 56037971100: 2
# Distances list for 56037970800: [5.723177448543173]
# Within radius count for 56037970800: 0
# Distances list for 56037970601: [4.034885586708853]
# Within radius count for 56037970601: 1
# Distances list for 56037971000: [5.215262641328385]
# Within radius count for 56037971000: 0
# Distances list for 56005000400: [0.5920511109567974, 0.27195254486367854, 0.2709767160193428, 0.14051485504670705, 0.6044078552847302, 0.6436770738648252]
# Within radius count for 56005000400: 6
# Distances list for 56005000200: [4.449800119718325]
# Within radius count for 56005000200: 1
# Distances list for 56023978100: [2.0297488838300164, 2.018793916597591]
# Within radius count for 56023978100: 2
# Distances list for 56023978400: [1.9551095745463758, 1.8925324696777683]
# Within radius count for 56023978400: 2
# Distances list for 56001963400: [0.4208490255713224, 0.3451145486542176, 0.21867698730473792, 0.40073134250100334]
# Within radius count for 56001963400: 4
# Distances list for 56023978001: [0.18488363239451414]
# Within radius count for 56023978001: 1
# Distances list for 56025000300: [0.5580765887171034]
# Within radius count for 56025000300: 1
# Distances list for 56025000200: [0.5624421037007343, 0.42829293038585514, 0.3871868271626882, 0.3545587351263402, 0.39048862288114644, 0.7426815210435489, 1.0135380650905625, 0.6781286686353709, 0.5545930319148419, 0.3483785398640332]
# Within radius count for 56025000200: 10
# Distances list for 56025000901: [0.4218045663841874]
# Within radius count for 56025000901: 1
# Distances list for 56025001100: [1.3144278033082286]
# Within radius count for 56025001100: 1
# Distances list for 56021001200: [1.1687762741830674, 0.29893187296768997]
# Within radius count for 56021001200: 2
# Distances list for 56029965500: [1.259353605223383, 1.5129797595664727, 0.8873918129646603, 1.2322509935638257, 1.5310164236101602, 1.3053201531856773]
# Within radius count for 56029965500: 6
# Distances list for 56021001401: [0.3995848195498523]
# Within radius count for 56021001401: 1
# Distances list for 56021001402: [1.7274784335150268, 1.5228349674346038, 1.4471994622184152, 1.7588195524841368, 1.6980357724779143]
# Within radius count for 56021001402: 5
# Distances list for 56029965200: [0.13820040188532604, 0.060867191747774906, 1.3527968252428282, 0.3354815262468241]
# Within radius count for 56029965200: 4
# Distances list for 56043000301: [0.17009214289875707, 0.4273043090113875, 0.33061364467871573, 0.26759119020766453, 0.23665543710859016, 0.26759119020766453]
# Within radius count for 56043000301: 6
# Distances list for 56045951100: [17.690222469260526]
# Within radius count for 56045951100: 0
# Distances list for 56045951300: [3.0121952491942103, 2.0733845878164874]
# Within radius count for 56045951300: 2
# Distances list for 56007967800: [1.342669137261706]
# Within radius count for 56007967800: 1
# Distances list for 56007968100: [9.08361953242253]
# Within radius count for 56007968100: 1
# Distances list for 56007967700: [1.6397783906860943]
# Within radius count for 56007967700: 1
# Distances list for 56007968000: [11.379578816317347]
# Within radius count for 56007968000: 0
# Distances list for 56021001501: [1.7352329226587666, 1.7400836397237343]
# Within radius count for 56021001501: 2
# Distances list for 56029965401: [1.5154504376965676, 1.431118062648929]
# Within radius count for 56029965401: 2
# Distances list for 56025000400: [0.14763768622883536, 0.2971058545014321]
# Within radius count for 56025000400: 2
# Distances list for 56025000800: [1.058180133755543]
# Within radius count for 56025000800: 1
# Distances list for 56039967701: [2.791369826349568, 2.820298859193504, 2.834187910634275, 3.681409277802371, 3.6261875215636388, 3.5622729618759448, 3.8518180386460394, 2.791369826349568]
# Within radius count for 56039967701: 8
# Distances list for 56017967800: [0.4915434344793262, 0.5302818795016553, 0.3737686385133975, 0.5317711070762471]
# Within radius count for 56017967800: 4
# Distances list for 56013000400: [5.763977733107181, 5.928005320415306]
# Within radius count for 56013000400: 2
# Distances list for 56013940500: [0.48435601448684, 0.4599537605870277, 0.19370325827172372, 0.21960158954327774]
# Within radius count for 56013940500: 4
# Distances list for 56013000100: [1.7508984488708474]
# Within radius count for 56013000100: 1
# Distances list for 56013000200: [2.7444690461496934, 2.7674769435525923, 2.3749491186809037, 2.037198513111836]
# Within radius count for 56013000200: 4
# Distances list for 56013940100: [22.109065588038103]
# Within radius count for 56013940100: 0
# Distances list for 56035000101: [6.022414473155931]
# Within radius count for 56035000101: 1
# Distances list for 56019955201: [1.025767238531849, 1.0430043815552053]
# Within radius count for 56019955201: 2
# Distances list for 56041975301: [10.22010901576769]
# Within radius count for 56041975301: 0
# Distances list for 56003962600: [11.740474142579375, 11.740474142579375]
# Within radius count for 56003962600: 0
# Distances list for 56033000100: [1.1106964985119319, 0.6997830011715624, 1.2114914435687345, 0.6455091175726324, 0.4897177510587695]
# Within radius count for 56033000100: 5
# Distances list for 56033000200: [0.6064440153068015, 0.7590941622261699]
# Within radius count for 56033000200: 2
# Distances list for 56031959100: [13.81466996672756]
# Within radius count for 56031959100: 0
# Distances list for 56027957200: [20.62727744834674, 20.850387863483803]
# Within radius count for 56027957200: 0
# Distances list for 56009956400: [5.024153517779149, 4.839199400834433, 4.837908147351489, 5.270453464581516, 4.950856113394588]
# Within radius count for 56009956400: 5
# Distances list for 56009956700: [1.8237129814161872]
# Within radius count for 56009956700: 1
#       STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 0          01      063  060101  01063060101  1400000US01063060101  601.01
# 1          01      069  040802  01069040802  1400000US01069040802  408.02
# 2          01      069  040205  01069040205  1400000US01069040205  402.05
# 3          01      069  040203  01069040203  1400000US01069040203  402.03
# 4          01      069  040801  01069040801  1400000US01069040801  408.01
# ...       ...      ...     ...          ...                   ...     ...
# 60737      56      021  000800  56021000800  1400000US56021000800       8
# 60738      56      027  957200  56027957200  1400000US56027957200    9572
# 60739      56      021  000200  56021000200  1400000US56021000200       2
# 60740      56      009  956400  56009956400  1400000US56009956400    9564
# 60741      56      009  956700  56009956700  1400000US56009956700    9567
#
#                   NAMELSAD  MTFCC FUNCSTAT       ALAND   AWATER   INTPTLAT  \
# 0      Census Tract 601.01  G5020        S    79177219   846346  32.779875
# 1      Census Tract 408.02  G5020        S    31146753   351369  31.149447
# 2      Census Tract 402.05  G5020        S     8597200    89063  31.231052
# 3      Census Tract 402.03  G5020        S    14602533        0  31.261332
# 4      Census Tract 408.01  G5020        S    20146185   217773  31.188587
# ...                    ...    ...      ...         ...      ...        ...
# 60737       Census Tract 8  G5020        S     1244409        0  41.149217
# 60738    Census Tract 9572  G5020        S  6801380678  4969450  43.062159
# 60739       Census Tract 2  G5020        S     7538613        0  41.124339
# 60740    Census Tract 9564  G5020        S   121226002   879080  42.796182
# 60741    Census Tract 9567  G5020        S    26097174   583365  42.844205
#
#          INTPTLON                                           geometry  \
# 0      -87.936632  POLYGON ((-87.99829 32.76851, -87.99326 32.771...
# 1      -85.418679  POLYGON ((-85.44941 31.15536, -85.44937 31.155...
# 2      -85.472151  POLYGON ((-85.50281 31.23736, -85.50261 31.238...
# 3      -85.474245  POLYGON ((-85.50379 31.24638, -85.50281 31.247...
# 4      -85.443952  POLYGON ((-85.47512 31.2079, -85.47504 31.2083...
# ...           ...                                                ...
# 60737 -104.798831  POLYGON ((-104.8093 41.14624, -104.80926 41.14...
# 60738 -104.468373  POLYGON ((-104.89994 43.49964, -104.89953 43.4...
# 60739 -104.808835  POLYGON ((-104.85109 41.11787, -104.85084 41.1...
# 60740 -105.299046  POLYGON ((-105.42173 42.80178, -105.42172 42.8...
# 60741 -105.843209  POLYGON ((-105.90686 42.85549, -105.90675 42.8...
#
#                 source_file Community Type  Radius Threshold in Miles  \
# 0      tl_2024_01_tract.shp          Urban                          2
# 1      tl_2024_01_tract.shp          Urban                          2
# 2      tl_2024_01_tract.shp          Urban                          2
# 3      tl_2024_01_tract.shp          Urban                          2
# 4      tl_2024_01_tract.shp          Urban                          2
# ...                     ...            ...                        ...
# 60737  tl_2024_56_tract.shp          Urban                          2
# 60738  tl_2024_56_tract.shp          Rural                         10
# 60739  tl_2024_56_tract.shp          Urban                          2
# 60740  tl_2024_56_tract.shp          Rural                         10
# 60741  tl_2024_56_tract.shp          Urban                          2
#
#           bank_desert_status
# 0                bank desert
# 1                bank desert
# 2      potential bank desert
# 3      potential bank desert
# 4                bank desert
# ...                      ...
# 60737            bank desert
# 60738            bank desert
# 60739            bank desert
# 60740      not a bank desert
# 60741  potential bank desert
#
# [60742 rows x 18 columns]

# %% [markdown]
# - The bank desert status will be used as a target variable for our binary classification model, it will be merged with the US Census Data based on GEOID
# - It will also be used in creating the interactive visualization showing the different census tracts filtered by state and county, overlayed with census data

# %%
# saving the census shapefile geodataframe with the bank desert status column as a parquet file
# cs_shp_with_BDS.to_parquet('shp_with_BDS.parquet')

# %%
cs_shp_with_BDS.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 60742 entries, 0 to 60741
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STATEFP                    60742 non-null  object
#  1   COUNTYFP                   60742 non-null  object
#  2   TRACTCE                    60742 non-null  object
#  3   GEOID                      60742 non-null  object
#  4   GEOIDFQ                    60742 non-null  object
#  5   NAME                       60742 non-null  object
#  6   NAMELSAD                   60742 non-null  object
#  7   MTFCC                      60742 non-null  object
#  8   FUNCSTAT                   60742 non-null  object
#  9   ALAND                      60742 non-null  int64
#  10  AWATER                     60742 non-null  int64
#  11  INTPTLAT                   60742 non-null  float64
#  12  INTPTLON                   60742 non-null  float64
#  13  geometry                   60742 non-null  geometry
#  14  source_file                60742 non-null  object
#  15  Community Type             60742 non-null  object
#  16  Radius Threshold in Miles  60742 non-null  int64
#  17  bank_desert_status         60742 non-null  object
# dtypes: float64(2), geometry(1), int64(3), object(12)
# memory usage: 8.3+ MB

# %%
cs_shp_with_BDS['bank_desert_status'].value_counts()
# Out:
# bank_desert_status
# bank desert              38657
# not a bank desert        11132
# potential bank desert    10953
# Name: count, dtype: int64

# %%
cs = cs_shp_with_BDS[cs_shp_with_BDS['GEOID'] == '01063060101']
bank = banks_gdf[banks_gdf['FIPS 11'] == '01063060101']

# %%
cs
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 0      01      063  060101  01063060101  1400000US01063060101  601.01
#
#               NAMELSAD  MTFCC FUNCSTAT     ALAND  AWATER   INTPTLAT  \
# 0  Census Tract 601.01  G5020        S  79177219  846346  32.779875
#
#     INTPTLON                                           geometry  \
# 0 -87.936632  POLYGON ((-87.99829 32.76851, -87.99326 32.771...
#
#             source_file Community Type  Radius Threshold in Miles  \
# 0  tl_2024_01_tract.shp          Urban                          2
#
#   bank_desert_status
# 0        bank desert

# %%
bank
# Out:
#         City State    ZIP                           Input Address State Code  \
# Index
# 54790  Eutaw    AL  35462  302 Prairie Ave, Eutaw, Alabama, 35462         01
#
#       County Code Tract Code Block Code  Longitude   Latitude      FIPS 11  \
# Index
# 54790         063     060101       2002 -87.887949  32.840092  01063060101
#
#                                                Bank Name  \
# Index
# 54790  Merchants & Farmers Bank Of Greene County, Ala...
#
#                          Geometry
# Index
# 54790  POINT (-87.88795 32.84009)

# %%
cs_shp_with_BDS.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 60742 entries, 0 to 60741
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STATEFP                    60742 non-null  object
#  1   COUNTYFP                   60742 non-null  object
#  2   TRACTCE                    60742 non-null  object
#  3   GEOID                      60742 non-null  object
#  4   GEOIDFQ                    60742 non-null  object
#  5   NAME                       60742 non-null  object
#  6   NAMELSAD                   60742 non-null  object
#  7   MTFCC                      60742 non-null  object
#  8   FUNCSTAT                   60742 non-null  object
#  9   ALAND                      60742 non-null  int64
#  10  AWATER                     60742 non-null  int64
#  11  INTPTLAT                   60742 non-null  float64
#  12  INTPTLON                   60742 non-null  float64
#  13  geometry                   60742 non-null  geometry
#  14  source_file                60742 non-null  object
#  15  Community Type             60742 non-null  object
#  16  Radius Threshold in Miles  60742 non-null  int64
#  17  bank_desert_status         60742 non-null  object
# dtypes: float64(2), geometry(1), int64(3), object(12)
# memory usage: 8.3+ MB

# %%
# saving the census shapefile geodataframe with the bank desert status column as a parquet file

# cs_shp_with_BDS.to_parquet('shp_with_BDS.parquet')
